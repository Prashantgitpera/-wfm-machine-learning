# %%
import matplotlib.pyplot as plt

age = [22, 25, 28, 30, 31, 32, 35, 35, 36, 38, 40, 42, 45, 48, 50]

plt.hist(age)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()
